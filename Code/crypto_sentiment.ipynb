# %%
import os
import pandas as pd
# %matplotlib inline

# Import pprint to use to preview
# pulled news
from pprint import pprint

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
from newsapi import NewsApiClient

# Retrieve the News API key
api_key = os.getenv("NEWSAPI_KEY")

# Check contents type of News API key variable
type(api_key)
# Out:
# str

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_news_en = newsapi.get_everything(
    q="bitcoin",
    language="en"
)

btc_news_en['articles'][0]['content']
# Out:
# "At least that's the idea. While it's not as intensive as mining Bitcoin, running a full node still requires a lot of computing power. In fact, HTC recommends only using the feature while the phone is connected to WiFi and plugged into its power adapter. The c… [+2014 chars]"

# %%
# Fetch the Ethereum news articles
eth_news_en = newsapi.get_everything(
    q="ethereum",
    language="en"
)
eth_news_en['articles'][0]['content']
# Out:
# "TL;DR: The in-depth Complete Blockchain and Ethereum Programmer bundle is on sale for just $24 with the code 20LEARN20.\r\nWhen it comes to Bitcoin, you get the gist: Cryptocurrency is on the rise right now, it's a worthy investment, and it when it comes to top… [+1491 chars]"

# %%
def create_df(news):
    articles = []
    for article in news:
        # Sentiment scoring with VADER
        text_sentiment = analyzer.polarity_scores(article['content'])
        try:
            compound = text_sentiment['compound']
            negative = text_sentiment['neg']
            neutral = text_sentiment['neu']
            positive = text_sentiment['pos']
            text = str(article['content'])

            articles.append({
                'Compound': compound,
                'Negative': negative,
                'Neutral': neutral,
                'Positive': positive,
                'Text': text
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_df = create_df(btc_news_en['articles'])
btc_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.2263     0.000    0.960     0.040
# 1   -0.6486     0.139    0.817     0.044
# 2   -0.7845     0.154    0.846     0.000
# 3   -0.4767     0.069    0.931     0.000
# 4    0.0258     0.080    0.859     0.061
#
#                                                 Text
# 0  At least that's the idea. While it's not as in...
# 1  Since its inception in 2009, Bitcoin has made ...
# 2  New allegations against a bitcoin developer sp...
# 3  Say it with me: Bitcoin is not anonymous. \r\n...
# 4  Federal authorities in the U.S. have unsealed ...

# %%
# Create the ethereum sentiment scores DataFrame
eth_df = create_df(eth_news_en["articles"])
eth_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.4404       0.0    0.941     0.059
# 1    0.3818       0.0    0.933     0.067
# 2    0.6249       0.0    0.900     0.100
# 3    0.2263       0.0    0.960     0.040
# 4    0.4601       0.0    0.915     0.085
#
#                                                 Text
# 0  TL;DR: The in-depth Complete Blockchain and Et...
# 1  IKEA Iceland has used Ethereum ETHtechnology t...
# 2  Disrupt Berlin is right around the corner. And...
# 3  At least that's the idea. While it's not as in...
# 4  he plaBy now, you should almost certainly know...

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.312675   0.024200   0.910650   0.065150
# std     0.439946   0.048259   0.037119   0.030386
# min    -0.784500   0.000000   0.817000   0.000000
# 25%     0.274900   0.000000   0.885250   0.060500
# 50%     0.507000   0.000000   0.931000   0.068000
# 75%     0.507000   0.010500   0.932000   0.069000
# max     0.687900   0.154000   0.960000   0.117000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.158165   0.031050   0.910200   0.058700
# std     0.377470   0.052945   0.072668   0.042425
# min    -0.823200   0.000000   0.735000   0.000000
# 25%     0.000000   0.000000   0.885000   0.030750
# 50%     0.238150   0.000000   0.930000   0.059000
# 75%     0.411525   0.045750   0.945750   0.075250
# max     0.624900   0.210000   1.000000   0.139000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Expand the default stop words list if necessary

# %%
# Complete the tokenizer function
def tokenizer(text):
    "Tokenizes text."
    
    # Create a list of the words
    words_tokenized = []
    for word in text:
        tokenized_words = word_tokenize(word['content'])
        words_tokenized.append(tokenized_words)
    
    # Convert the words to lowercase
    words_lower = [[word.lower()for word in words] for words in words_tokenized]
    
    # Remove the stop words and punctuation
    # (Could not figure out how to remove punctuation
    # before removing stop words)
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = [[regex.sub('', word) for word in words] for words in words_lower]
    
    # Lemmatize Words into root words
    tokens = [[lemmatizer.lemmatize(word) for word in words] for words in re_clean]
    
    return tokens

# %%
# Create a new tokens column for bitcoin
btc_df['Tokens'] = tokenizer(btc_news_en['articles'])
btc_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.2263     0.000    0.960     0.040
# 1    -0.6486     0.139    0.817     0.044
# 2    -0.7845     0.154    0.846     0.000
# 3    -0.4767     0.069    0.931     0.000
# 4     0.0258     0.080    0.859     0.061
# 5     0.4404     0.000    0.941     0.059
# 6     0.5070     0.000    0.933     0.067
# 7     0.5070     0.000    0.932     0.068
# 8     0.5070     0.000    0.932     0.068
# 9     0.5070     0.000    0.931     0.069
# 10    0.6879     0.000    0.886     0.114
# 11    0.5070     0.000    0.931     0.069
# 12    0.5530     0.000    0.926     0.074
# 13    0.5070     0.000    0.932     0.068
# 14    0.6879     0.000    0.883     0.117
# 15    0.2911     0.042    0.893     0.065
# 16    0.5070     0.000    0.932     0.068
# 17    0.5070     0.000    0.932     0.068
# 18    0.6879     0.000    0.883     0.117
# 19    0.5070     0.000    0.933     0.067
#
#                                                  Text  \
# 0   At least that's the idea. While it's not as in...
# 1   Since its inception in 2009, Bitcoin has made ...
# 2   New allegations against a bitcoin developer sp...
# 3   Say it with me: Bitcoin is not anonymous. \r\n...
# 4   Federal authorities in the U.S. have unsealed ...
# 5   TL;DR: The in-depth Complete Blockchain and Et...
# 6   Our robot colleague Satoshi Nakaboto writes ab...
# 7   Our robot colleague Satoshi Nakaboto writes ab...
# 8   Our robot colleague Satoshi Nakaboto writes ab...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  Our robot colleague Satoshi Nakaboto writes ab...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...
# 19  Our robot colleague Satoshi Nakaboto writes ab...
#
#                                                Tokens
# 0   [at, least, that, s, the, idea, , while, it, s...
# 1   [since, it, inception, in, , , bitcoin, ha, ma...
# 2   [new, allegation, against, a, bitcoin, develop...
# 3   [say, it, with, me, , bitcoin, is, not, anonym...
# 4   [federal, authority, in, the, u, have, unseale...
# 5   [tl, , dr, , the, indepth, complete, blockchai...
# 6   [our, robot, colleague, satoshi, nakaboto, wri...
# 7   [our, robot, colleague, satoshi, nakaboto, wri...
# 8   [our, robot, colleague, satoshi, nakaboto, wri...
# 9   [our, robot, colleague, satoshi, nakaboto, wri...
# 10  [our, robot, colleague, satoshi, nakaboto, wri...
# 11  [our, robot, colleague, satoshi, nakaboto, wri...
# 12  [our, robot, colleague, satoshi, nakaboto, wri...
# 13  [our, robot, colleague, satoshi, nakaboto, wri...
# 14  [our, robot, colleague, satoshi, nakaboto, wri...
# 15  [our, robot, colleague, satoshi, nakaboto, wri...
# 16  [our, robot, colleague, satoshi, nakaboto, wri...
# 17  [our, robot, colleague, satoshi, nakaboto, wri...
# 18  [our, robot, colleague, satoshi, nakaboto, wri...
# 19  [our, robot, colleague, satoshi, nakaboto, wri...

# %%
# Create a new tokens column for ethereum
eth_df['Tokens'] = tokenizer(eth_news_en['articles'])
eth_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.4404     0.000    0.941     0.059
# 1     0.3818     0.000    0.933     0.067
# 2     0.6249     0.000    0.900     0.100
# 3     0.2263     0.000    0.960     0.040
# 4     0.4601     0.000    0.915     0.085
# 5     0.4019     0.000    0.932     0.068
# 6     0.1027     0.054    0.882     0.063
# 7     0.2500     0.033    0.911     0.056
# 8     0.0000     0.000    1.000     0.000
# 9    -0.5095     0.082    0.886     0.032
# 10   -0.8232     0.210    0.735     0.055
# 11    0.5781     0.030    0.838     0.132
# 12    0.0258     0.000    0.973     0.027
# 13   -0.3818     0.066    0.934     0.000
# 14    0.1779     0.103    0.758     0.139
# 15    0.5719     0.000    0.928     0.072
# 16    0.2960     0.043    0.837     0.120
# 17    0.0000     0.000    1.000     0.000
# 18    0.0000     0.000    1.000     0.000
# 19    0.3400     0.000    0.941     0.059
#
#                                                  Text  \
# 0   TL;DR: The in-depth Complete Blockchain and Et...
# 1   IKEA Iceland has used Ethereum ETHtechnology t...
# 2   Disrupt Berlin is right around the corner. And...
# 3   At least that's the idea. While it's not as in...
# 4   he plaBy now, you should almost certainly know...
# 5   TLDR: The Complete Blockchain and Ethereum Pro...
# 6   Further to its previous blockchain exploits, t...
# 7   Australias Perth Mint, one of the worlds large...
# 8   Announced at Ethereum Foundation's Devcon 5 co...
# 9   The total transactional volume of blockchain a...
# 10  MakerDAO, the decentralized organization that ...
# 11  Good morning Forkers, you know what time it is...
# 12  The central bank of Venezuela is reportedly lo...
# 13  Reuters\r\n<ul><li>Bitcoin slumped as much as ...
# 14  The firm behind blockchain-powered cloud compu...
# 15  Lately, headlines have been flooded with news ...
# 16  Controversial USD-backed stablecoin Tether is ...
# 17  i-Space, a Bejing-based space company, showed ...
# 18  Vodafone is running an augmented reality (AR) ...
# 19  UK police raised £300,000 ($369,000) through t...
#
#                                                Tokens
# 0   [tl, , dr, , the, indepth, complete, blockchai...
# 1   [ikea, iceland, ha, used, ethereum, ethtechnol...
# 2   [disrupt, berlin, is, right, around, the, corn...
# 3   [at, least, that, s, the, idea, , while, it, s...
# 4   [he, plaby, now, , you, should, almost, certai...
# 5   [tldr, , the, complete, blockchain, and, ether...
# 6   [further, to, it, previous, blockchain, exploi...
# 7   [australia, perth, mint, , one, of, the, world...
# 8   [announced, at, ethereum, foundation, s, devco...
# 9   [the, total, transactional, volume, of, blockc...
# 10  [makerdao, , the, decentralized, organization,...
# 11  [good, morning, forkers, , you, know, what, ti...
# 12  [the, central, bank, of, venezuela, is, report...
# 13  [reuters, , ul, , , li, , bitcoin, slumped, a,...
# 14  [the, firm, behind, blockchainpowered, cloud, ...
# 15  [lately, , headline, have, been, flooded, with...
# 16  [controversial, usdbacked, stablecoin, tether,...
# 17  [ispace, , a, bejingbased, space, company, , s...
# 18  [vodafone, is, running, an, augmented, reality...
# 19  [uk, police, raised, , , , , , through, the, a...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def bigram_counter(article_list): 
    # Combine all articles in corpus into one large string
    big_string = []
    for article in article_list:
        string = ''.join(article['content'])
        big_string.append(string)
    tokenized = [word_tokenize(word) for word in big_string]
    flat_list = [item for sublist in tokenized for item in sublist]
    bigrams = ngrams(flat_list, n=2)
    top_bigrams = dict(Counter(bigrams).most_common(20))
    return top_bigrams

# %%
"""
bigram counter when source is the articles
straight from the API

def bigram_counter(article_list): 
    # Combine all articles in corpus into one large string
    big_string = []
    for article in article_list:
        string = ''.join(article['content'])
        big_string.append(string)
    tokenized = [word_tokenize(word) for word in big_string]
    flat_list = [item for sublist in tokenized for item in sublist]
    bigrams = ngrams(flat_list, n=2)
    top_bigrams = dict(Counter(bigrams).most_common(20))
    return top_bigrams
"""
# Out:
# "\nbigram counter when source is the articles\nstraight from the API\n\ndef bigram_counter(article_list): \n    # Combine all articles in corpus into one large string\n    big_string = []\n    for article in article_list:\n        string = ''.join(article['content'])\n        big_string.append(string)\n    tokenized = [word_tokenize(word) for word in big_string]\n    flat_list = [item for sublist in tokenized for item in sublist]\n    bigrams = ngrams(flat_list, n=2)\n    top_bigrams = dict(Counter(bigrams).most_common(20))\n    return top_bigrams\n"

# %%
# Generate the Bitcoin N-grams where N=2
bigram_counter(btc_news_en['articles'])
# Out:
# {('Satoshi', 'Nakaboto'): 28,
#  ('chars', ']'): 20,
#  ('in', 'the'): 15,
#  ('Welcome', 'to'): 15,
#  (']', 'Our'): 14,
#  ('Our', 'robot'): 14,
#  ('robot', 'colleague'): 14,
#  ('colleague', 'Satoshi'): 14,
#  ('Nakaboto', 'writes'): 14,
#  ('writes', 'about'): 14,
#  ('about', 'Bitcoin'): 14,
#  ('Bitcoin', 'BTC'): 14,
#  ('BTC', 'every'): 14,
#  ('every', 'fucking'): 14,
#  ('fucking', 'day'): 14,
#  ('day', '.'): 14,
#  ('.', 'Welcome'): 14,
#  ('to', 'another'): 14,
#  ('another', 'edition'): 14,
#  ('edition', 'of'): 14}

# %%
# Generate the Ethereum N-grams where N=2
bigram_counter(eth_news_en['articles'])
# Out:
# {('chars', ']'): 20,
#  ('…', '['): 7,
#  ('.', 'The'): 6,
#  ('of', 'the'): 5,
#  (',', 'and'): 4,
#  ('Bitcoin', ','): 3,
#  (',', 'you'): 3,
#  ('now', ','): 3,
#  ('with', 'a'): 3,
#  ('Ethereum', ','): 3,
#  (',', 'the'): 3,
#  ('.', 'According'): 3,
#  ('According', 'to'): 3,
#  (']', 'The'): 3,
#  ('to', 'the'): 3,
#  ('dark', 'mode'): 3,
#  (':', 'The'): 2,
#  ('Complete', 'Blockchain'): 2,
#  ('Blockchain', 'and'): 2,
#  ('and', 'Ethereum'): 2}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens_list, N=10):
    """Returns the top N tokens from the frequency count"""
    for tokens in tokens_list:
        return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
btc_top_ten = token_count(btc_df['Tokens'])
btc_top_ten
# Out:
# [('', 8),
#  ('the', 4),
#  ('a', 4),
#  ('s', 2),
#  ('while', 2),
#  ('it', 2),
#  ('power', 2),
#  ('at', 1),
#  ('least', 1),
#  ('that', 1)]

# %%
# Get the top 10 words for Ethereum
eth_top_ten = token_count(eth_df['Tokens'])
eth_top_ten
# Out:
# [('', 12),
#  ('the', 4),
#  ('it', 4),
#  ('and', 2),
#  ('is', 2),
#  ('on', 2),
#  ('when', 2),
#  ('come', 2),
#  ('to', 2),
#  ('tl', 1)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
def column_iter(tokens_column):
    crypto_tokens = []
    for tokens_list in tokens_column:
        for tokens in tokens_list:
            crypto_tokens.append(tokens)
    big_string = ' '.join(crypto_tokens)
    return big_string

# %%
# Generate the Bitcoin word cloud
btc_tokens = column_iter(btc_df['Tokens'])

wc = WordCloud().generate(btc_tokens)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
eth_tokens = column_iter(eth_df['Tokens'])
eth_tokens

wc = WordCloud().generate(eth_tokens)
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
btc_tokens
# Out:
# 'at least that s the idea  while it s not a intensive a mining bitcoin  running a full node still requires a lot of computing power  in fact  htc recommends only using the feature while the phone is connected to wifi and plugged into it power adapter  the c   char  since it inception in   bitcoin ha made and ruined fortune  helped sell fentanyl and book about cryptocurrency  withstood literally million of joke and just a many prediction of imminent collapse  andthrough a process opaque to most people  myself   char  new allegation against a bitcoin developer spurred a deposition from jacob appelbaum photo by ingo wagner  getty image in the summer of   a flood of abuse allegation came out against celebrity tor developer jacob appelbaum  a shocking blow to one of   char  say it with me  bitcoin is not anonymous  three hundred and thirtyseven alleged member of a massive dark web child pornography website were reminded of that fact last year when they were arrested by a global coalition of law enforcement  according to a de   char  federal authority in the u have unsealed charge against the south korean operator of a child porn ring thats been billed a the world largest dark web child porn marketplace  the child porn site  known a welcome to video  charged some user in bitcoin   char  tl  dr  the indepth complete blockchain and ethereum programmer bundle is on sale for just   with the code learn  when it come to bitcoin  you get the gist  cryptocurrency is on the rise right now  it s a worthy investment  and it when it come to top   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a rousseau used to say  let get this br   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a satoshi nakamoto used to say  the long   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a baudriallard used to say  bob your un   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a aristotle used to say  your imaginatio   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a planck used to say  yolo  bitcoin pri   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a bentham used to say  your imagination    char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a nietzsche used to say  time is money     char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a baudriallard used to say  let get thi   char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking day  welcome to another edition of bitcoin today  where i  satoshi nakaboto  tell you whats been going on with bitcoin in the past  hour  a habermass used to say  yolo  bitcoin    char  our robot colleague satoshi nakaboto writes about bitcoin btc every fucking d ...

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_tokens)

# Add a title to the document

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">at least that s the idea  while it s not a intensive a mining bitcoin  running a full node still requires a lot of computing power  in fact  htc recommends only using the feature while the phone is connected to wifi and plugged into it power adapter  the c   char  since it inception in   bitcoin ha made and ruined fortune  helped sell fentanyl and book about cryptocurrency  withstood literally
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of joke and just a many prediction of imminent collapse  andthrough a process opaque to most people  myself   char  new allegation against a bitcoin developer spurred a deposition from
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     jacob appelbaum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  photo by ingo wagner  getty image in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of   a flood of abuse allegation came out against celebrity tor developer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     jacob appelbaum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# a shocking blow to one of   char  say it with me  bitcoin is not anonymous
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     three hundred and thirtyseven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  alleged member of a massive dark web child pornography website were reminded of that fact
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when they were arrested by a global coalition of law enforcement  according to a de   char  federal authority in the u have unsealed charge against the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     south korean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  operator of a child porn ring thats been billed a the world largest dark web child porn marketplace  the child porn site  known a welcome to video  charged some user in bitcoin   char  tl  dr  the indepth complete blockchain and ethereum programmer bundle is on sale for just   with the code learn  when it come to bitcoin  you get the gist  cryptocurrency is on the rise right now  it s a worthy investment  and it when it come to top   char  our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     satoshi nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about bitcoin btc every fucking day  welcome to another edition of bitcoin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   where i  satoshi nakaboto  tell you whats been going on with bitcoin in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the past  hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#   a rousseau used to say  let get this br   char  our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     satoshi nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about bitcoin btc every fucking day  welcome to another edition of bitcoin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   where i  satoshi nakaboto  tell you whats been going on with bitcoin in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the past  hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#   a satoshi nakamoto used to say  the long   char  our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     satoshi nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about bitcoin btc every fucking day  welcome to another edition of bitcoin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35e

# %%
# List all Entities
btc_entities = [ent.text for ent in btc_doc.ents]
btc_entities
# Out:
# ['million',
#  'jacob appelbaum',
#  'the summer',
#  'jacob appelbaum  ',
#  'three hundred and thirtyseven',
#  'last year',
#  'south korean',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'un',
#  'char',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'yolo  ',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'yolo  ',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour  ',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour',
#  'yolo  ',
#  'satoshi nakaboto',
#  'today',
#  'the past  hour  ',
#  'nikola']

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_tokens
# Out:
# 'tl  dr  the indepth complete blockchain and ethereum programmer bundle is on sale for just   with the code learn  when it come to bitcoin  you get the gist  cryptocurrency is on the rise right now  it s a worthy investment  and it when it come to top   char  ikea iceland ha used ethereum ethtechnology to settle an invoice with a local retailer  accepting payment in blockchainified digital cash  supply chain payment firm tradeshift facilitated the transfer using an ethereumbased version of the icelandic krna    char  disrupt berlin is right around the corner  and there is plenty to look forward to  join u december  and december  to hear from industry leader  investor  and bright star in the startup world  we  ll sit down with ceo from bigname company such a a   char  at least that s the idea  while it s not a intensive a mining bitcoin  running a full node still requires a lot of computing power  in fact  htc recommends only using the feature while the phone is connected to wifi and plugged into it power adapter  the c   char  he plaby now  you should almost certainly know about ethereum  eth the second largest cryptocurrency by market cap  but if you needed a quick recap  here it is  ethereums creator wanted to build a platform that would allow user all over the world to write    char  tldr  the complete blockchain and ethereum programming bundle help you understand cryptocurrencies and it root technology for under    everybodys got an opinion about cryptocurrencies and their future place in international finance  a leading cryptos con   char  further to it previous blockchain exploit  the united nation childrens fund  more commonly known a unicef  is now taking donation in cryptocurrency  according to an announcement earlier today  unicef is setting up a cryptocurrency fund so that it can re   char  australia perth mint  one of the world largest refinery  is today launching a goldbacked ethereum eth token guaranteed by the government of western australia  marketing material shared with hard fork claim the perth mint gold token  pmgt  is the first    char  announced at ethereum foundation s devcon  conference in osaka  japan  openlibra is described a an  open platform for financial inclusion   with a telling tagline   not run by facebook   openlibra aim to be compatible with libra in a technical sense  meani   char  the total transactional volume of blockchain apps  dapps  across the six major dappcentric network hit just   billion last quarter  down by nearly  percent  more troubling  just  dapps launched in q of this year  thats le than the monthlyaverag   char  makerdao  the decentralized organization that run on ethereum  eth ha disclosed an enormously dangerous security flaw that couldve allowed an attacker to steal all of the collateral powering it dai stablecoin with a single transaction  the bug  if exploit   char  good morning forkers  you know what time it is  it moonday morning  hard fork wrapup of the weekend top cryptocurrency and blockchain headline you cant afford to miss  check it out    the ukrainian government is allegedly preparing plan to legalize    char  the central bank of venezuela is reportedly looking into whether it can store cryptocurrencies in it coffer  bloomberg report citing four anonymous individual close to the matter  according to the report the bank investigation follows a request by petro   char  reuters  ul   li  bitcoin slumped a much a   on wednesday  hitting it lowest level since june  ahead of facebook ceo mark zuckerberg s testimonial on the company s proposed cryptocurrency  libra   li   li  zuckerberg is due to answer question from a hous   char  the firm behind blockchainpowered cloud computing service eos eos must pay   million for violating u security law with it initial coin offering  ico   blockone did not register it ico a a security offering pursuant to the federal security law     char  lately  headline have been flooded with news of dark mode rolling out to more apps than  ...

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_tokens)

# Add a title to the document

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">tl  dr  the indepth complete blockchain and ethereum programmer bundle is on sale for just   with the code learn  when it come to bitcoin  you get the gist  cryptocurrency is on the rise right now  it s a worthy investment  and it when it come to top   char  ikea iceland ha used ethereum ethtechnology to settle an invoice with a local retailer  accepting payment in blockchainified digital cash  supply chain payment firm tradeshift facilitated the transfer using an ethereumbased version of the icelandic krna    char  disrupt
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is right around the corner  and there is plenty to look forward to  join u
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     december
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     december
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   to hear from industry leader  investor  and bright star in the startup world  we  ll sit down with ceo from bigname company such a a   char  at least that s the idea  while it s not a intensive a mining bitcoin  running a full node still requires a lot of computing power  in fact  htc recommends only using the feature while the phone is connected to wifi and plugged into it power adapter  the c   char  he plaby now  you should almost certainly know about ethereum  eth the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  largest cryptocurrency by market cap  but if you needed a quick recap  here it is  ethereums creator wanted to build a platform that would allow user all over the world to write    char  tldr  the complete blockchain and ethereum programming bundle help you understand cryptocurrencies and it root technology for under    everybodys got an opinion about cryptocurrencies and their future place in international finance  a leading cryptos con   char  further to it previous blockchain exploit  the united nation childrens fund  more commonly known a unicef  is now taking donation in cryptocurrency  according to an announcement earlier
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   unicef is setting up a cryptocurrency fund so that it can re   char  australia perth mint  one of the world largest refinery  is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  launching a goldbacked ethereum eth token guaranteed by the government of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     western australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# marketing material shared with hard fork claim the perth mint gold token  pmgt  is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#     char  announced at ethereum foundation s devcon  conference in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     osaka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   openlibra is described a an  open platform for financial inclusion   with a telling tagline   not run by facebook   openlibra aim to be compatible with libra in a technical sense  meani   char  the total transactional volume of blockchain apps  dapps  across the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  major dappcentric network hit just   billion
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#   down by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     nearly  percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#   more troubling  just  dapps launched in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     q of this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertic

# %%
# List all Entities
eth_entities = [ent.text for ent in eth_doc.ents]
eth_entities
# Out:
# ['berlin',
#  'december',
#  'december',
#  'second',
#  'today',
#  'today',
#  'western australia  ',
#  'first',
#  'osaka',
#  'japan',
#  'six',
#  'last quarter',
#  'nearly  percent',
#  'q of this year',
#  'char  makerdao  ',
#  'char  good',
#  'the weekend',
#  'ukrainian',
#  'venezuela',
#  'four',
#  'char  reuters',
#  'li  ',
#  'wednesday',
#  'june',
#  'mark zuckerberg',
#  'li',
#  'li  zuckerberg',
#  'the world fourth',
#  'only percent',
#  'first',
#  'last week',
#  'chinese',
#  'us',
#  'char  ',
#  'london',
#  'uk',
#  'this week',
#  'first',
#  'uk',
#  'two']
